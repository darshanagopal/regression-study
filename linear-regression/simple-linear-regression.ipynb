# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')

# %%
print(data.head(5))
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
#linear equation
#Y = Xa + b

# Features (Experience Years)
X = data[['Experience Years']].values.reshape(-1, 1)

# Target (Salary)
Y = data['Salary'].values

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %% [markdown]
# Slope indicates how much the salary is expected to increase for each additional year of experience. For instance, if the slope is $5,000, it means that each additional year of experience is associated with a $5,000 increase in salary.

# %%
# Plot the data points
plt.scatter(X, Y, color='blue', label='Actual Salary')

# Plot the regression line
plt.plot(X, y_pred, color='red', label='Regression Line')

# Add labels and title
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Simple Linear Regression')
plt.legend()

# Show the plot
plt.show()
